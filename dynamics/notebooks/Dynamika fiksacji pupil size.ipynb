# %%
import pandas as pd
from os.path import join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.rcParams["figure.figsize"] = [10, 6]

# %% [markdown]
# # Analiza dynamiki fiksacji
# ## Analiza A - dynamika w funkcji wybranej odpowiedzi

# %%
Lmin = 2
Lmax = 22
WINDOW_SIZE = 5
results = join('..', 'results', 'results_pup')

# %%
### DATA LOADING
corr = pd.read_csv(join(results, 'dynamics_CORR.csv'))
err = pd.read_csv(join(results, 'dynamics_ERR.csv'))
full = pd.read_csv(join(results, 'dynamics_FULL.csv'))

lev_easy_corr = pd.read_csv(join(results, 'dynamics_LEV_EASY_CORR.csv'))
lev_med_corr = pd.read_csv(join(results, 'dynamics_LEV_MED_CORR.csv'))
lev_hard_corr = pd.read_csv(join(results, 'dynamics_LEV_HARD_CORR.csv'))

lev_easy_err = pd.read_csv(join(results, 'dynamics_LEV_EASY_ERR.csv'))
lev_med_err = pd.read_csv(join(results, 'dynamics_LEV_MED_ERR.csv'))
lev_hard_err = pd.read_csv(join(results, 'dynamics_LEV_HARD_ERR.csv'))

lev_easy_full = pd.read_csv(join(results, 'dynamics_LEV_EASY_FULL.csv'))
lev_med_full = pd.read_csv(join(results, 'dynamics_LEV_MED_FULL.csv'))
lev_hard_full = pd.read_csv(join(results, 'dynamics_LEV_HARD_FULL.csv'))

wmc_low_corr = pd.read_csv(join(results, 'dynamics_WMC_LOW_CORR.csv'))
wmc_low_err = pd.read_csv(join(results, 'dynamics_WMC_LOW_ERR.csv'))
wmc_low_full = pd.read_csv(join(results, 'dynamics_WMC_LOW_FULL.csv'))
wmc_med_corr = pd.read_csv(join(results, 'dynamics_WMC_MED_CORR.csv'))
wmc_med_err = pd.read_csv(join(results, 'dynamics_WMC_MED_ERR.csv'))
wmc_med_full = pd.read_csv(join(results, 'dynamics_WMC_MED_FULL.csv'))
wmc_high_corr = pd.read_csv(join(results, 'dynamics_WMC_HIGH_CORR.csv'))
wmc_high_err = pd.read_csv(join(results, 'dynamics_WMC_HIGH_ERR.csv'))
wmc_high_full = pd.read_csv(join(results, 'dynamics_WMC_HIGH_FULL.csv'))

wmc_low_lev_easy = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_EASY.csv'))
wmc_med_lev_easy = pd.read_csv(join(results, 'dynamics_WMC_MED_LEV_EASY.csv'))
wmc_high_lev_easy = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_EASY.csv'))

wmc_low_lev_med = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_MED.csv'))
wmc_med_lev_med = pd.read_csv(join(results, 'dynamics_WMC_MED_LEV_MED.csv'))
wmc_high_lev_med = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_MED.csv'))

wmc_low_lev_hard = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_HARD.csv'))
wmc_med_lev_hard = pd.read_csv(join(results, 'dynamics_WMC_MED_LEV_HARD.csv'))
wmc_high_lev_hard = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_HARD.csv'))


#CORRECTIONS LOADING

# CI_corr_lev_easy = pd.read_csv(join(results, 'dynamics_CI_CORR_LEV_EASY.csv'))
# CI_corr_lev_med = pd.read_csv(join(results, 'dynamics_CI_CORR_LEV_MED.csv'))
# CI_corr_lev_hard = pd.read_csv(join(results, 'dynamics_CI_CORR_LEV_HARD.csv'))

# CI_err_lev_easy = pd.read_csv(join(results, 'dynamics_CI_ERR_LEV_EASY.csv'))
# CI_err_lev_med = pd.read_csv(join(results, 'dynamics_CI_ERR_LEV_MED.csv'))
# CI_err_lev_hard = pd.read_csv(join(results, 'dynamics_CI_ERR_LEV_HARD.csv'))

# Divide PROP by WINDOW SIZE, TO MAKE IT PROPORTIONAL 
# corr_lev_easy['PROP_FOx'] /= WINDOW_SIZE
# corr_lev_med['PROP_FOx'] /= WINDOW_SIZE
# corr_lev_hard['PROP_FOx'] /= WINDOW_SIZE
# err_lev_easy['PROP_FOx'] /= WINDOW_SIZE
# err_lev_med['PROP_FOx'] /= WINDOW_SIZE
# err_lev_hard['PROP_FOx'] /= WINDOW_SIZE
# wmc_low_lev_easy['PROP_FOx'] /= WINDOW_SIZE
# wmc_med_lev_easy['PROP_FOx'] /= WINDOW_SIZE
# wmc_high_lev_easy['PROP_FOx'] /= WINDOW_SIZE
# wmc_low_lev_med['PROP_FOx'] /= WINDOW_SIZE
# wmc_med_lev_med['PROP_FOx'] /= WINDOW_SIZE
# wmc_high_lev_med['PROP_FOx'] /= WINDOW_SIZE
# wmc_low_lev_hard['PROP_FOx'] /= WINDOW_SIZE
# wmc_med_lev_hard['PROP_FOx'] /= WINDOW_SIZE
# wmc_high_lev_hard['PROP_FOx'] /= WINDOW_SIZE

# corr_lev_easy['FOx_STD'] /= WINDOW_SIZE
# corr_lev_med['FOx_STD'] /= WINDOW_SIZE
# corr_lev_hard['FOx_STD'] /= WINDOW_SIZE
# err_lev_easy['FOx_STD'] /= WINDOW_SIZE
# err_lev_med['FOx_STD'] /= WINDOW_SIZE
# err_lev_hard['FOx_STD'] /= WINDOW_SIZE
# wmc_low_lev_easy['FOx_STD'] /= WINDOW_SIZE
# wmc_med_lev_easy['FOx_STD'] /= WINDOW_SIZE
# wmc_high_lev_easy['FOx_STD'] /= WINDOW_SIZE
# wmc_low_lev_med['FOx_STD'] /= WINDOW_SIZE
# wmc_med_lev_med['FOx_STD'] /= WINDOW_SIZE
# wmc_high_lev_med['FOx_STD'] /= WINDOW_SIZE
# wmc_low_lev_hard['FOx_STD'] /= WINDOW_SIZE
# wmc_med_lev_hard['FOx_STD'] /= WINDOW_SIZE
# wmc_high_lev_hard['FOx_STD'] /= WINDOW_SIZE


# CI_corr_lev_easy['FOx_STD'] /= WINDOW_SIZE
# CI_corr_lev_med['FOx_STD'] /= WINDOW_SIZE
# CI_corr_lev_hard['FOx_STD'] /= WINDOW_SIZE
# CI_err_lev_easy['FOx_STD'] /= WINDOW_SIZE
# CI_err_lev_med['FOx_STD'] /= WINDOW_SIZE
# CI_err_lev_hard['FOx_STD'] /= WINDOW_SIZE

# %%
corr['PROP_PSOx'] /= WINDOW_SIZE
err['PROP_PSOx'] /= WINDOW_SIZE
full['PROP_PSOx'] /= WINDOW_SIZE

lev_easy_corr['PROP_PSOx'] /= WINDOW_SIZE
lev_med_corr['PROP_PSOx'] /= WINDOW_SIZE
lev_hard_corr['PROP_PSOx'] /= WINDOW_SIZE

lev_easy_err['PROP_PSOx'] /= WINDOW_SIZE
lev_med_err['PROP_PSOx'] /= WINDOW_SIZE
lev_hard_err['PROP_PSOx'] /= WINDOW_SIZE

lev_easy_full['PROP_PSOx'] /= WINDOW_SIZE
lev_med_full['PROP_PSOx'] /= WINDOW_SIZE
lev_hard_full['PROP_PSOx'] /= WINDOW_SIZE

wmc_low_corr['PROP_PSOx'] /= WINDOW_SIZE
wmc_low_err['PROP_PSOx'] /= WINDOW_SIZE
wmc_low_full['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_corr['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_err['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_full['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_corr['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_err['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_full['PROP_PSOx'] /= WINDOW_SIZE

wmc_low_lev_easy['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_lev_easy['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_lev_easy['PROP_PSOx'] /= WINDOW_SIZE

wmc_low_lev_med['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_lev_med['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_lev_med['PROP_PSOx'] /= WINDOW_SIZE

wmc_low_lev_hard['PROP_PSOx'] /= WINDOW_SIZE
wmc_med_lev_hard['PROP_PSOx'] /= WINDOW_SIZE
wmc_high_lev_hard['PROP_PSOx'] /= WINDOW_SIZE




corr['PSOx_STD'] /= WINDOW_SIZE
err['PSOx_STD'] /= WINDOW_SIZE
full['PSOx_STD'] /= WINDOW_SIZE

lev_easy_corr['PSOx_STD'] /= WINDOW_SIZE
lev_med_corr['PSOx_STD'] /= WINDOW_SIZE
lev_hard_corr['PSOx_STD'] /= WINDOW_SIZE

lev_easy_err['PSOx_STD'] /= WINDOW_SIZE
lev_med_err['PSOx_STD'] /= WINDOW_SIZE
lev_hard_err['PSOx_STD'] /= WINDOW_SIZE

lev_easy_full['PSOx_STD'] /= WINDOW_SIZE
lev_med_full['PSOx_STD'] /= WINDOW_SIZE
lev_hard_full['PSOx_STD'] /= WINDOW_SIZE

wmc_low_corr['PSOx_STD'] /= WINDOW_SIZE
wmc_low_err['PSOx_STD'] /= WINDOW_SIZE
wmc_low_full['PSOx_STD'] /= WINDOW_SIZE
wmc_med_corr['PSOx_STD'] /= WINDOW_SIZE
wmc_med_err['PSOx_STD'] /= WINDOW_SIZE
wmc_med_full['PSOx_STD'] /= WINDOW_SIZE
wmc_high_corr['PSOx_STD'] /= WINDOW_SIZE
wmc_high_err['PSOx_STD'] /= WINDOW_SIZE
wmc_high_full['PSOx_STD'] /= WINDOW_SIZE

wmc_low_lev_easy['PSOx_STD'] /= WINDOW_SIZE
wmc_med_lev_easy['PSOx_STD'] /= WINDOW_SIZE
wmc_high_lev_easy['PSOx_STD'] /= WINDOW_SIZE

wmc_low_lev_med['PSOx_STD'] /= WINDOW_SIZE
wmc_med_lev_med['PSOx_STD'] /= WINDOW_SIZE
wmc_high_lev_med['PSOx_STD'] /= WINDOW_SIZE

wmc_low_lev_hard['PSOx_STD'] /= WINDOW_SIZE
wmc_med_lev_hard['PSOx_STD'] /= WINDOW_SIZE
wmc_high_lev_hard['PSOx_STD'] /= WINDOW_SIZE

# %%
# PROP_PSOx

# %% [markdown]
# # Predziały ufności
# 1.96 razy odchylenie standardowe danej miary (tzn. albo PROP_FO albo AVG_RM) podzielone przez pierwiastek kwadratowy z liczby triali dla tej sekundy (czyli Kx): 1.96*(SDx/SQRT(Kx)) [inaczej 1.96 razy błąd standardowy miary w danej sekundzie].

# %%
def add_CI(data, param, corr = None):
    N = {'PROP_FOx': 'Kx', 'AVG_RMx': 'RMk', 'PROP_PSOx': 'Kx'}[param]
    STD = {'PROP_FOx': 'FOx_STD', 'AVG_RMx': 'RMx_STD', 'PROP_PSOx':'PSOx_STD'}[param]
    if not (corr is None):
        data[param + '_low_CI'] = data[param] - (1.96 * corr[STD] / np.sqrt(corr[N]))
        data[param + '_high_CI'] = data[param] + (1.96 * corr[STD] / np.sqrt(corr[N]))
    else:
        data[param + '_low_CI'] = data[param] - (1.96 * data[STD] / np.sqrt(data[N]))
        data[param + '_high_CI'] = data[param] + (1.96 * data[STD] / np.sqrt(data[N]))
    
def plot_CI(data, param,labels, title):
    # Define a function for the line plot with intervals
    _, ax = plt.subplots()

    # Plot the data, set the linewidth, color and transparency of the
    # line, provide a label for the legend
    ax.plot([x * WINDOW_SIZE for x in data[0][param].index.tolist()],
            data[0][param].tolist(), 
            lw = 1,
            color = 'green',
            alpha = 1,
            label = labels[0])
    # Shade the confidence interval
    ax.fill_between([x * WINDOW_SIZE for x in data[0][param].index.tolist()],
                    data[0][param+"_low_CI"],
                    data[0][param+"_high_CI"], 
                    color = 'green',
                    alpha = 0.4,
                    label = '95% CI')

    ax.plot([x * WINDOW_SIZE for x in data[1][param].index.tolist()],
            data[1][param].tolist(), 
            lw = 1,
            color = 'red',
            alpha = 1,
            label = labels[1])
    # Shade the confidence interval
    ax.fill_between([x * WINDOW_SIZE for x in data[1][param].index.tolist()],
                    data[1][param+"_low_CI"],
                    data[1][param+"_high_CI"], 
                    color = 'red',
                    alpha = 0.4,
                    label = '95% CI')
    if len(data) == 3:
        ax.plot([x * WINDOW_SIZE for x in data[2][param].index.tolist()],
                data[2][param].tolist(), 
                lw = 1,
                color = 'blue',
                alpha = 1,
                label = labels[2])
        # Shade the confidence interval
        ax.fill_between([x * WINDOW_SIZE for x in data[2][param].index.tolist()],
                        data[2][param+"_low_CI"],
                        data[2][param+"_high_CI"], 
                        color = 'blue',
                        alpha = 0.4,
                        label = '95% CI')

    # Label the axes and provide a title
    ax.set_title(title)
    ax.set_xlabel('Time of experiment(s)')
    ax.set_ylabel(param)
    ax.set_xlim([WINDOW_SIZE * Lmin,WINDOW_SIZE * (Lmax-1)])
#     ax.set_ylim([0,1])

        # Display legend
    ax.legend(loc = 'best')

# %%
add_CI(corr, 'PROP_PSOx')
add_CI(err, 'PROP_PSOx')
add_CI(full, 'PROP_PSOx')

add_CI(lev_easy_corr, 'PROP_PSOx')
add_CI(lev_med_corr, 'PROP_PSOx')
add_CI(lev_hard_corr, 'PROP_PSOx')

add_CI(lev_easy_err, 'PROP_PSOx')
add_CI(lev_med_err, 'PROP_PSOx')
add_CI(lev_hard_err, 'PROP_PSOx')

add_CI(lev_easy_full, 'PROP_PSOx')
add_CI(lev_med_full, 'PROP_PSOx')
add_CI(lev_hard_full, 'PROP_PSOx')

add_CI(wmc_low_corr, 'PROP_PSOx')
add_CI(wmc_low_err, 'PROP_PSOx')
add_CI(wmc_low_full, 'PROP_PSOx')

add_CI(wmc_med_corr, 'PROP_PSOx')
add_CI(wmc_med_err, 'PROP_PSOx')
add_CI(wmc_med_full, 'PROP_PSOx')

add_CI(wmc_high_corr, 'PROP_PSOx')
add_CI(wmc_high_err, 'PROP_PSOx')
add_CI(wmc_high_full, 'PROP_PSOx')

add_CI(wmc_low_lev_easy, 'PROP_PSOx')
add_CI(wmc_med_lev_easy, 'PROP_PSOx')
add_CI(wmc_high_lev_easy, 'PROP_PSOx')

add_CI(wmc_low_lev_med, 'PROP_PSOx')
add_CI(wmc_med_lev_med, 'PROP_PSOx')
add_CI(wmc_high_lev_med, 'PROP_PSOx')

add_CI(wmc_low_lev_hard, 'PROP_PSOx')
add_CI(wmc_med_lev_hard, 'PROP_PSOx')
add_CI(wmc_high_lev_hard, 'PROP_PSOx')

# %% [markdown]
# # Plots

# %%
plot_CI([corr, err, full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'FULL DATA')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_easy_corr, lev_med_corr, lev_hard_corr], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'CORR VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_easy_err, lev_med_err, lev_hard_err], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'ERR VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_easy_full, lev_med_full, lev_hard_full], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'FULL VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_easy_corr, lev_easy_err, lev_easy_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'LEV EASY VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_med_corr, lev_med_err, lev_med_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'LEV MED VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([lev_hard_corr, lev_hard_err, lev_hard_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'LEV HARD VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_full, wmc_med_full, wmc_high_full], 'PROP_PSOx', ['LOW', 'MED', 'HIGH'], 'WMC LEVEL FULL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_corr, wmc_med_corr, wmc_high_corr], 'PROP_PSOx', ['LOW', 'MED', 'HIGH'], 'WMC LEVEL CORR')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_err, wmc_med_err, wmc_high_err], 'PROP_PSOx', ['LOW', 'MED', 'HIGH'], 'WMC LEVEL ERR')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_corr, wmc_low_err, wmc_low_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'WMC LOW VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_med_corr, wmc_med_err, wmc_med_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'WMC MED VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_high_corr, wmc_high_err, wmc_high_full], 'PROP_PSOx', ['CORR', 'ERR', 'FULL'], 'WMC HIGH VS CORRECTNESS')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_lev_easy, wmc_low_lev_med, wmc_low_lev_hard], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'WMC LOW VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_med_lev_easy, wmc_med_lev_med, wmc_med_lev_hard], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'WMC MED VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_high_lev_easy, wmc_high_lev_med, wmc_high_lev_hard], 'PROP_PSOx', ['EASY', 'MED', 'HARD'], 'WMC HIGH VS LEVEL')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_lev_easy, wmc_med_lev_easy, wmc_high_lev_easy], 'PROP_PSOx', ['LOW', 'MED', 'HiGH'], 'LEVEL EASY VS WMC')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_lev_med, wmc_med_lev_med, wmc_high_lev_med], 'PROP_PSOx', ['LOW', 'MED', 'HiGH'], 'LEVEL MED VS WMC')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plot_CI([wmc_low_lev_hard, wmc_med_lev_hard, wmc_high_lev_hard], 'PROP_PSOx', ['LOW', 'MED', 'HiGH'], 'LEVEL HARD VS WMC')
# Out:
# <img src="data:image/png;base64,..." width="1000">
