# %%
# import jtplot submodule from jupyterthemes
# from jupyterthemes import jtplot

# currently installed theme will be used to
# set plot style if no arguments provided
# jtplot.style()
import pandas as pd
from os.path import join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from matplotlib import gridspec
import matplotlib as mpl
mpl.style.use('seaborn-whitegrid')
plt.rcParams["figure.figsize"] = [11.69, 8.27]
# mpl.style.available

# %%
Lmin = 2
Lmax = 22
WINDOW_SIZE = 5
PUP_SIZE_SCALE = 0.004 * 0.2
results = join('..', 'results', 'results_review_08_2021')

# %% [markdown]
# # Relational options on correctness

# %%
### DATA LOADING
wmc_low_lev_easy = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_EASY.csv'))
wmc_low_lev_med = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_MED.csv'))
wmc_low_lev_hard = pd.read_csv(join(results, 'dynamics_WMC_LOW_LEV_HARD.csv'))

wmc_high_lev_easy = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_EASY.csv'))
wmc_high_lev_med = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_MED.csv'))
wmc_high_lev_hard = pd.read_csv(join(results, 'dynamics_WMC_HIGH_LEV_HARD.csv'))

corr_wmc_low_lev_easy = pd.read_csv(join(results, 'dynamics_CORR_WMC_LOW_LEV_EASY.csv'))
corr_wmc_low_lev_med = pd.read_csv(join(results, 'dynamics_CORR_WMC_LOW_LEV_MED.csv'))
corr_wmc_low_lev_hard = pd.read_csv(join(results, 'dynamics_CORR_WMC_LOW_LEV_HARD.csv'))

corr_wmc_high_lev_easy = pd.read_csv(join(results, 'dynamics_CORR_WMC_HIGH_LEV_EASY.csv'))
corr_wmc_high_lev_med = pd.read_csv(join(results, 'dynamics_CORR_WMC_HIGH_LEV_MED.csv'))
corr_wmc_high_lev_hard = pd.read_csv(join(results, 'dynamics_CORR_WMC_HIGH_LEV_HARD.csv'))

err_wmc_low_lev_easy = pd.read_csv(join(results, 'dynamics_ERR_WMC_LOW_LEV_EASY.csv'))
err_wmc_low_lev_med = pd.read_csv(join(results, 'dynamics_ERR_WMC_LOW_LEV_MED.csv'))
err_wmc_low_lev_hard = pd.read_csv(join(results, 'dynamics_ERR_WMC_LOW_LEV_HARD.csv'))

err_wmc_high_lev_easy = pd.read_csv(join(results, 'dynamics_ERR_WMC_HIGH_LEV_EASY.csv'))
err_wmc_high_lev_med = pd.read_csv(join(results, 'dynamics_ERR_WMC_HIGH_LEV_MED.csv'))
err_wmc_high_lev_hard = pd.read_csv(join(results, 'dynamics_ERR_WMC_HIGH_LEV_HARD.csv'))

# Correct trials aggregated over item types
# T1 = pd.read_csv(join(results, '1.csv'))
# T2 = pd.read_csv(join(results, '2.csv'))
# T3 = pd.read_csv(join(results, '3.csv'))
# T4 = pd.read_csv(join(results, '4.csv'))
# T5 = pd.read_csv(join(results, '5.csv'))
# T6 = pd.read_csv(join(results, '6.csv'))
# T7 = pd.read_csv(join(results, '7.csv'))

wmc_low_lev_easy['AVG_RMx'] *= 100
wmc_low_lev_med['AVG_RMx'] *= 100
wmc_low_lev_hard['AVG_RMx'] *= 100
wmc_high_lev_easy['AVG_RMx'] *= 100
wmc_high_lev_med['AVG_RMx'] *= 100
wmc_high_lev_hard['AVG_RMx'] *= 100

corr_wmc_low_lev_easy['AVG_RMx'] *= 100
corr_wmc_low_lev_med['AVG_RMx'] *= 100
corr_wmc_low_lev_hard['AVG_RMx'] *= 100
corr_wmc_high_lev_easy['AVG_RMx'] *= 100
corr_wmc_high_lev_med['AVG_RMx'] *= 100
corr_wmc_high_lev_hard['AVG_RMx'] *= 100

err_wmc_low_lev_easy['AVG_RMx'] *= 100
err_wmc_low_lev_med['AVG_RMx'] *= 100
err_wmc_low_lev_hard['AVG_RMx'] *= 100
err_wmc_high_lev_easy['AVG_RMx'] *= 100
err_wmc_high_lev_med['AVG_RMx'] *= 100
err_wmc_high_lev_hard['AVG_RMx'] *= 100

wmc_low_lev_easy['RMx_STD'] *= 100
wmc_low_lev_med['RMx_STD'] *= 100
wmc_low_lev_hard['RMx_STD'] *= 100
wmc_high_lev_easy['RMx_STD'] *= 100
wmc_high_lev_med['RMx_STD'] *= 100
wmc_high_lev_hard['RMx_STD'] *= 100

corr_wmc_low_lev_easy['RMx_STD'] *= 100
corr_wmc_low_lev_med['RMx_STD'] *= 100
corr_wmc_low_lev_hard['RMx_STD'] *= 100
corr_wmc_high_lev_easy['RMx_STD'] *= 100
corr_wmc_high_lev_med['RMx_STD'] *= 100
corr_wmc_high_lev_hard['RMx_STD'] *= 100

err_wmc_low_lev_easy['RMx_STD'] *= 100
err_wmc_low_lev_med['RMx_STD'] *= 100
err_wmc_low_lev_hard['RMx_STD'] *= 100
err_wmc_high_lev_easy['RMx_STD'] *= 100
err_wmc_high_lev_med['RMx_STD'] *= 100
err_wmc_high_lev_hard['RMx_STD'] *= 100

# full_wmc_low['PROP_PSOx'] *= PUP_SIZE_SCALE
# full_wmc_med['PROP_PSOx'] *= PUP_SIZE_SCALE
# full_wmc_high['PROP_PSOx'] *= PUP_SIZE_SCALE
# corr_wmc_low['PROP_PSOx'] *= PUP_SIZE_SCALE
# corr_wmc_med['PROP_PSOx'] *= PUP_SIZE_SCALE
# corr_wmc_high['PROP_PSOx'] *= PUP_SIZE_SCALE
# err_wmc_low['PROP_PSOx'] *= PUP_SIZE_SCALE
# err_wmc_med['PROP_PSOx'] *= PUP_SIZE_SCALE
# err_wmc_high['PROP_PSOx'] *= PUP_SIZE_SCALE

# full_wmc_low['PSOx_mean'] *= PUP_SIZE_SCALE
# full_wmc_med['PSOx_mean'] *= PUP_SIZE_SCALE
# full_wmc_high['PSOx_mean'] *= PUP_SIZE_SCALE
# corr_wmc_low['PSOx_mean'] *= PUP_SIZE_SCALE
# corr_wmc_med['PSOx_mean'] *= PUP_SIZE_SCALE
# corr_wmc_high['PSOx_mean'] *= PUP_SIZE_SCALE
# err_wmc_low['PSOx_mean'] *= PUP_SIZE_SCALE
# err_wmc_med['PSOx_mean'] *= PUP_SIZE_SCALE
# err_wmc_high['PSOx_mean'] *= PUP_SIZE_SCALE

# full_wmc_low['PSOx_STD'] *= PUP_SIZE_SCALE
# full_wmc_med['PSOx_STD'] *= PUP_SIZE_SCALE
# full_wmc_high['PSOx_STD'] *= PUP_SIZE_SCALE
# c['PSOx_STD'] *= PUP_SIZE_SCALE
# corr_wmc_med['PSOx_STD'] *= PUP_SIZE_SCALE
# corr_wmc_high['PSOx_STD'] *= PUP_SIZE_SCALE
# err_wmc_low['PSOx_STD'] *= PUP_SIZE_SCALE
# err_wmc_med['PSOx_STD'] *= PUP_SIZE_SCALE
# err_wmc_high['PSOx_STD'] *= PUP_SIZE_SCALE

# full['FOX_aggregated'] *= 100


# T1['AVG_RMx'] *= 100
# T2['AVG_RMx'] *= 100
# T3['AVG_RMx'] *= 100
# T4['AVG_RMx'] *= 100
# T5['AVG_RMx'] *= 100
# T6['AVG_RMx'] *= 100
# T7['AVG_RMx'] *= 100

# CI_corr_lev_easy['RMx_STD'] *= 100
# CI_corr_lev_med['RMx_STD'] *= 100
# CI_corr_lev_hard['RMx_STD'] *= 100

# CI_err_lev_easy['RMx_STD'] *= 100
# CI_err_lev_med['RMx_STD'] *= 100
# CI_err_lev_hard['RMx_STD'] *= 100

# corr_lev_easy['PROP_PSOx'] /= WINDOW_SIZE
# corr_lev_med['PROP_PSOx'] /= WINDOW_SIZE
# corr_lev_hard['PROP_PSOx'] /= WINDOW_SIZE

# err_lev_easy['PROP_PSOx'] /= WINDOW_SIZE
# err_lev_med['PROP_PSOx'] /= WINDOW_SIZE
# err_lev_hard['PROP_PSOx'] /= WINDOW_SIZE

# corr_lev_easy['PSOx_STD'] /= WINDOW_SIZE
# corr_lev_med['PSOx_STD'] /= WINDOW_SIZE
# corr_lev_hard['PSOx_STD'] /= WINDOW_SIZE

# err_lev_easy['PSOx_STD'] /= WINDOW_SIZE
# err_lev_med['PSOx_STD'] /= WINDOW_SIZE
# err_lev_hard['PSOx_STD'] /= WINDOW_SIZE

# corr_lev_easy['PROP_PSOx'] *= PUP_SIZE_SCALE
# corr_lev_med['PROP_PSOx'] *= PUP_SIZE_SCALE
# corr_lev_hard['PROP_PSOx'] *= PUP_SIZE_SCALE

# err_lev_easy['PROP_PSOx'] *= PUP_SIZE_SCALE
# err_lev_med['PROP_PSOx'] *= PUP_SIZE_SCALE
# err_lev_hard['PROP_PSOx'] *= PUP_SIZE_SCALE

# corr_lev_easy['PSOx_STD'] *= PUP_SIZE_SCALE
# corr_lev_med['PSOx_STD'] *= PUP_SIZE_SCALE
# corr_lev_hard['PSOx_STD'] *= PUP_SIZE_SCALE

# err_lev_easy['PSOx_STD'] *= PUP_SIZE_SCALE
# err_lev_med['PSOx_STD'] *= PUP_SIZE_SCALE
# err_lev_hard['PSOx_STD'] *= PUP_SIZE_SCALE

# %%
def add_CI(data, param, corr = None):
    N = {'PROP_FOx': 'Kx', 'AVG_RMx': 'RMk', 'PROP_PSOx': 'Kx', 'PSOx_mean': 'Kx'}[param]
    STD = {'PROP_FOx': 'FOx_STD', 'AVG_RMx': 'RMx_STD', 'PROP_PSOx':'PSOx_STD', 'PSOx_mean': 'PSOx_STD'}[param]
    if not (corr is None):
        data[param + '_low_CI'] = data[param] - (1.96 * corr[STD] / np.sqrt(corr[N]))
        data[param + '_high_CI'] = data[param] + (1.96 * corr[STD] / np.sqrt(corr[N]))
    else:
        data[param + '_low_CI'] = data[param] - (1.96 * data[STD] / np.sqrt(data[N]))
        data[param + '_high_CI'] = data[param] + (1.96 * data[STD] / np.sqrt(data[N]))

# %%
# add_CI(corr_lev_easy, 'AVG_RMx', corr = CI_corr_lev_easy)
# add_CI(err_lev_easy,'AVG_RMx', corr = CI_err_lev_easy)
# add_CI(corr_lev_med, 'AVG_RMx', corr = CI_corr_lev_med)
# add_CI(err_lev_med,'AVG_RMx', corr = CI_err_lev_med)
# add_CI(corr_lev_hard, 'AVG_RMx', corr = CI_corr_lev_hard)
# add_CI(err_lev_hard,'AVG_RMx', corr = CI_err_lev_hard)

# add_CI(full_wmc_low,'AVG_RMx')
# add_CI(full_wmc_med, 'AVG_RMx')
# add_CI(full_wmc_high,'AVG_RMx')

# add_CI(full_wmc_low,'PSOx_mean')
# add_CI(full_wmc_med, 'PSOx_mean')
# add_CI(full_wmc_high,'PSOx_mean')


# add_CI(corr_wmc_low,'AVG_RMx')
# add_CI(corr_wmc_med, 'AVG_RMx')
# add_CI(corr_wmc_high,'AVG_RMx')

# add_CI(corr_wmc_low,'AVG_RMx')
# add_CI(corr_wmc_med, 'AVG_RMx')
# add_CI(corr_wmc_high,'AVG_RMx')

# add_CI(full_wmc_low,'PROP_PSOx')
# add_CI(full_wmc_med, 'PROP_PSOx')
# add_CI(full_wmc_high,'PROP_PSOx')

# add_CI(corr_wmc_low,'PROP_PSOx')
# add_CI(corr_wmc_med, 'PROP_PSOx')
# add_CI(corr_wmc_high,'PROP_PSOx')

# add_CI(corr_wmc_low,'PROP_PSOx')
# add_CI(corr_wmc_med, 'PROP_PSOx')
# add_CI(corr_wmc_high,'PROP_PSOx')

add_CI(wmc_low_lev_easy,'AVG_RMx')
add_CI(wmc_low_lev_med, 'AVG_RMx')
add_CI(wmc_low_lev_hard,'AVG_RMx')
add_CI(wmc_high_lev_easy,'AVG_RMx')
add_CI(wmc_high_lev_med, 'AVG_RMx')
add_CI(wmc_high_lev_hard,'AVG_RMx')

add_CI(corr_wmc_low_lev_easy,'AVG_RMx')
add_CI(corr_wmc_low_lev_med, 'AVG_RMx')
add_CI(corr_wmc_low_lev_hard,'AVG_RMx')
add_CI(corr_wmc_high_lev_easy,'AVG_RMx')
add_CI(corr_wmc_high_lev_med, 'AVG_RMx')
add_CI(corr_wmc_high_lev_hard,'AVG_RMx')

add_CI(err_wmc_low_lev_easy,'AVG_RMx')
add_CI(err_wmc_low_lev_med, 'AVG_RMx')
add_CI(err_wmc_low_lev_hard,'AVG_RMx')
add_CI(err_wmc_high_lev_easy,'AVG_RMx')
add_CI(err_wmc_high_lev_med, 'AVG_RMx')
add_CI(err_wmc_high_lev_hard,'AVG_RMx')

# %% [markdown]
# # Dynamics of mapping in the time course of analogies

# %%
x_ticks = np.arange(0, (WINDOW_SIZE * wmc_high_lev_hard.shape[0]), WINDOW_SIZE)
# Define a function for the line plot with intervals
# gs = gridspec.GridSpec(17, 2)

f = plt.figure()
f.tight_layout()
f, axes = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=False)

ax1, ax2, ax3 = axes[0], axes[1], axes[2]
# ax1 = axes[0, 0]
# ax2 = axes[0, 1]
# ax3 = axes[0, 2]
# ax4 = axes[1, 0]
# ax5 = axes[1, 1]
# ax6 = axes[1, 2]
# Plot the data, set the linewidth, color and transparency of the
# line, provide a label for the legend

# ax1 = plt.subplot(gs[0:5, 0])
ax1.plot(
    x_ticks,
    corr_wmc_low_lev_easy['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax1.fill_between(
    x_ticks,
    corr_wmc_low_lev_easy['AVG_RMx_low_CI'],
    corr_wmc_low_lev_easy['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)

ax1.plot(
    x_ticks,
    corr_wmc_high_lev_easy['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax1.fill_between(
    x_ticks,
    corr_wmc_high_lev_easy['AVG_RMx_low_CI'],
    corr_wmc_high_lev_easy['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)
# ax2 = plt.subplot(gs[6:11, 0])
ax2.plot(
    x_ticks,
    corr_wmc_low_lev_med['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax2.fill_between(
    x_ticks,
    corr_wmc_low_lev_med['AVG_RMx_low_CI'],
    corr_wmc_low_lev_med['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)

ax2.plot(
    x_ticks,
    corr_wmc_high_lev_med['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax2.fill_between(
    x_ticks,
    corr_wmc_high_lev_med['AVG_RMx_low_CI'],
    corr_wmc_high_lev_med['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)

# Plot the data, set the linewidth, color and transparency of the
# line, provide a label for the legend
# ax3 = plt.subplot(gs[12:17, 0])
ax3.plot(
    x_ticks,
    corr_wmc_low_lev_hard['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax3.fill_between(
    x_ticks,
    corr_wmc_low_lev_hard['AVG_RMx_low_CI'],
    corr_wmc_low_lev_hard['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)

ax3.plot(
    x_ticks,
    corr_wmc_high_lev_hard['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax3.fill_between(
    x_ticks,
    corr_wmc_high_lev_hard['AVG_RMx_low_CI'],
    corr_wmc_high_lev_hard['AVG_RMx_high_CI'],
    color='dimgray',
    alpha=0.25)

# Label the axes and provide a title
ax1.set_title('Low-RM analogies', size=14)

ax2.set_title('Medium-RM analogies', size=14)
ax1.set_ylabel(
    '    Mean relational match (RM) of options fixated on in epoch      ', {
        'size': 14,
        'fontstretch': 'ultra-expanded'
    })

ax3.set_title('High-RM analogies', size=14)


ax1.tick_params(labelsize=10)
ax1.set_xticks(range(0, 111, 20))
ax1.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax2.set_xticks(range(0, 111, 20))
ax2.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax3.set_xticks(range(0, 111, 20))
ax3.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)


ax1.set_xlim([0, 100])
ax2.set_xlim([0, 100])
ax3.set_xlim([0, 100])
# ax4.set_xlim([0, 110])
# ax5.set_xlim([0, 110])
# ax6.set_xlim([0, 110])

ax1.set_ylim([20, 80])
ax2.set_ylim([50, 90])
ax3.set_ylim([70, 95])
# ax4.set_ylim([40, 90])
# ax5.set_ylim([10, 30])
# ax6.set_ylim([0, 100])

# Display legend
#ax1.legend(loc='upper left', fontsize=10)
# ax2.legend(loc='upper left', fontsize=10)
ax2.legend(loc='lower right', fontsize=10)
ax2.set_xlabel('Consecutive 5-s epochs of trials', {'size': 16, 'fontstretch': 'ultra-expanded'})

f.suptitle('Dynamics of mapping in the time course of analogies \n' +
           'as a function of working memory capacity ' +
           'for correct trials.', size=21)
# ax1.legend(loc = 'best')
# f.savefig('panel_5x1_review.png')
plt.subplots_adjust(wspace=0.12, hspace=0.09)
f.savefig("rev_corr_08_2021_95.png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1169">
# <img src="data:image/png;base64,..." width="1169">

# %%
x_ticks = np.arange(0, (WINDOW_SIZE * wmc_high_lev_hard.shape[0]), WINDOW_SIZE)
# Define a function for the line plot with intervals
# gs = gridspec.GridSpec(17, 2)

f = plt.figure()
f.tight_layout()
f, axes = plt.subplots(nrows=3, ncols=1, sharex=True, sharey=False)

ax1, ax2, ax3 = axes[0], axes[1], axes[2]
# ax1 = axes[0, 0]
# ax2 = axes[0, 1]
# ax3 = axes[0, 2]
# ax4 = axes[1, 0]
# ax5 = axes[1, 1]
# ax6 = axes[1, 2]
# Plot the data, set the linewidth, color and transparency of the
# line, provide a label for the legend

# ax1 = plt.subplot(gs[0:5, 0])
ax1.plot(
    x_ticks,
    err_wmc_low_lev_easy['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax1.fill_between(
    x_ticks,
    err_wmc_low_lev_easy['AVG_RMx_low_CI'],
    err_wmc_low_lev_easy['AVG_RMx_high_CI'],
    color='green',
    alpha=0.25)

ax1.plot(
    x_ticks,
    err_wmc_high_lev_easy['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax1.fill_between(
    x_ticks,
    err_wmc_high_lev_easy['AVG_RMx_low_CI'],
    err_wmc_high_lev_easy['AVG_RMx_high_CI'],
    color='blue',
    alpha=0.25)
# ax2 = plt.subplot(gs[6:11, 0])
ax2.plot(
    x_ticks,
    err_wmc_low_lev_med['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax2.fill_between(
    x_ticks,
    err_wmc_low_lev_med['AVG_RMx_low_CI'],
    err_wmc_low_lev_med['AVG_RMx_high_CI'],
    color='green',
    alpha=0.25)

ax2.plot(
    x_ticks,
    err_wmc_high_lev_med['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax2.fill_between(
    x_ticks,
    err_wmc_high_lev_med['AVG_RMx_low_CI'],
    err_wmc_high_lev_med['AVG_RMx_high_CI'],
    color='blue',
    alpha=0.25)

# Plot the data, set the linewidth, color and transparency of the
# line, provide a label for the legend
# ax3 = plt.subplot(gs[12:17, 0])
ax3.plot(
    x_ticks,
    err_wmc_low_lev_hard['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC LOW')
# Shade the confidence interval
ax3.fill_between(
    x_ticks,
    err_wmc_low_lev_hard['AVG_RMx_low_CI'],
    err_wmc_low_lev_hard['AVG_RMx_high_CI'],
    color='green',
    alpha=0.25)

ax3.plot(
    x_ticks,
    err_wmc_high_lev_hard['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC HIGH')
# Shade the confidence interval
ax3.fill_between(
    x_ticks,
    err_wmc_high_lev_hard['AVG_RMx_low_CI'],
    err_wmc_high_lev_hard['AVG_RMx_high_CI'],
    color='blue',
    alpha=0.25)

# Label the axes and provide a title
ax1.set_title('Low-RM analogies', size=14)

ax2.set_title('Medium-RM analogies', size=14)
ax2.set_ylabel(
    '    Mean relational match (RM) of options fixated on in epoch      ', {
        'size': 12,
        'fontstretch': 'ultra-expanded'
    })

ax3.set_title('High-RM analogies', size=14)


ax1.tick_params(labelsize=10)
ax1.set_xticks(range(0, 111, 20))
ax1.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax2.set_xticks(range(0, 111, 20))
ax2.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax3.set_xticks(range(0, 111, 20))
ax3.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)


ax1.set_xlim([0, 100])
ax2.set_xlim([0, 100])
ax3.set_xlim([0, 100])
# ax4.set_xlim([0, 110])
# ax5.set_xlim([0, 110])
# ax6.set_xlim([0, 110])

ax1.set_ylim([10, 70])
ax2.set_ylim([50, 80])
ax3.set_ylim([60, 90])
# ax4.set_ylim([40, 90])
# ax5.set_ylim([10, 30])
# ax6.set_ylim([0, 100])

# Display legend
ax1.legend(loc='upper left', fontsize=10)
ax2.legend(loc='upper left', fontsize=10)
ax2.legend(loc='lower right', fontsize=10)

f.suptitle('Dynamics of mapping in the time course of analogies as \n a function of working memory capacity for incorrect trials', size=22)
# ax1.legend(loc = 'best')
# f.savefig('panel_5x1_review.png')
f.savefig("rev_err_08_2021.png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1169">
# <img src="data:image/png;base64,..." width="1169">

# %%
# Dynamics of processing in the time course of Figural Analogy trials as a function of working memory capacity

# %%
corr_wmc_low['PROP_PSOx'].plot()
plt.show()

# %%
x_ticks = np.arange(0, (WINDOW_SIZE * corr_lev_easy.shape[0]), WINDOW_SIZE)
f, (ax1, ax2) = plt.subplots(1, 2, figsize= [ 11.6, 8.27])
# f.tight_layout()

ax1.plot(
    x_ticks,
    full_wmc_low['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC LOW')

ax1.fill_between(
    x_ticks,
    full_wmc_low['AVG_RMx_low_CI'],
    full_wmc_low['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax1.plot(
    x_ticks,
    full_wmc_med['AVG_RMx'], ':',
    lw=1,
    color='dimgray',
    label='WMC MED')

ax1.fill_between(
    x_ticks,
    full_wmc_med['AVG_RMx_low_CI'],
    full_wmc_med['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax1.plot(
    x_ticks,
    full_wmc_high['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC HIGH')

ax1.fill_between(
    x_ticks,
    full_wmc_high['AVG_RMx_low_CI'],
    full_wmc_high['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_low['PROP_PSOx'] ,label = 'WMC LOW', lw=1, color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_low['PROP_PSOx_low_CI'],
    full_wmc_low['PROP_PSOx_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_med['PROP_PSOx'],':' , label = 'WMC MED', lw = 1, color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_med['PROP_PSOx_low_CI'],
    full_wmc_med['PROP_PSOx_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_high['PROP_PSOx'], '--', lw=1, label='WMC HIGH', color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_high['PROP_PSOx_low_CI'],
    full_wmc_high['PROP_PSOx_high_CI'],
    color='gray',
    alpha=0.3)


ax1.set_xlim([0, 110])
ax1.set_ylim([50, 90])

ax2.set_xlim([10, 110])
ax2.set_ylim([4.5, 7.5])
# ax2.set_xticks([10, 30, 50, 70, 90, 110])

ax1.set_ylabel('Mean RM of options fixated across epoch', size=14)
ax2.set_ylabel('Mean pupil size during fixations on options (in mm)', size=14)

ax1.set_xticks(range(0, 111, 20))
ax1.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax2.set_xticks(range(10, 111, 20))
ax2.set_xticklabels(['10s', '30s', '50s', '70s', '90s', '110s'], size=9)

ax1.set_xlabel('Consecutive 5-s epochs of trials', {'size': 12})
ax2.set_xlabel('Consecutive 5-s epochs of trials', {'size': 12})
ax2.legend(loc = 'lower right')
f.suptitle("Dynamics of mapping in the time course of analogies as a function of working memory capacity", x = 0.5, y = 0.93, size=16)
f.savefig('FAN_WMC_Kx.png')

# %%
x_ticks = np.arange(0, (WINDOW_SIZE * corr_lev_easy.shape[0]), WINDOW_SIZE)
f, (ax1, ax2) = plt.subplots(1, 2, figsize= [ 11.6, 8.27])
# f.tight_layout(w_pad = 1.6, h_pad = 2)
ax1.plot(
    x_ticks,
    full_wmc_low['AVG_RMx'],
    lw=1,
    color='dimgray',
    label='WMC LOW')

ax1.fill_between(
    x_ticks,
    full_wmc_low['AVG_RMx_low_CI'],
    full_wmc_low['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax1.plot(
    x_ticks,
    full_wmc_med['AVG_RMx'], ':',
    lw=1,
    color='dimgray',
    label='WMC MED')

ax1.fill_between(
    x_ticks,
    full_wmc_med['AVG_RMx_low_CI'],
    full_wmc_med['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax1.plot(
    x_ticks,
    full_wmc_high['AVG_RMx'],
    '--',
    lw=1,
    color='dimgray',
    label='WMC HIGH')

ax1.fill_between(
    x_ticks,
    full_wmc_high['AVG_RMx_low_CI'],
    full_wmc_high['AVG_RMx_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_low['PSOx_mean'] ,label = 'WMC LOW', lw=1, color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_low['PSOx_mean_low_CI'],
    full_wmc_low['PSOx_mean_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_med['PSOx_mean'],':' , label = 'WMC MED', lw = 1, color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_med['PSOx_mean_low_CI'],
    full_wmc_med['PSOx_mean_high_CI'],
    color='gray',
    alpha=0.3)

ax2.plot(x_ticks, full_wmc_high['PSOx_mean'], '--', lw=1, label='WMC HIGH', color = 'dimgray')

ax2.fill_between(
    x_ticks,
    full_wmc_high['PSOx_mean_low_CI'],
    full_wmc_high['PSOx_mean_high_CI'],
    color='gray',
    alpha=0.3)


ax1.set_xlim([0, 110])
ax1.set_ylim([50, 90])

ax2.set_xlim([0, 110])
ax2.set_ylim([5.25, 6.75])
ax2.set_yticks(np.arange(5.25, 6.99, 0.25))
# ax2.set_xticks([10, 30, 50, 70, 90, 110])

ax1.set_ylabel('Mean relational match (RM) of options fixated on in an epoch', size=12)
ax2.set_ylabel('Mean pupil size during fixations of response options (in mm)', size=12)

ax1.set_xticks(range(0, 111, 20))
ax1.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)
ax2.set_xticks(range(0, 111, 20))
ax2.set_xticklabels(['0s', '20s', '40s', '60s', '80s', '100s'], size=9)

ax1.set_xlabel('Consecutive 5-s epochs of trials', {'size': 12})
ax2.set_xlabel('Consecutive 5-s epochs of trials', {'size': 12})
ax2.legend(loc = 'lower right')
f.suptitle("Dynamics of mapping in the time course of analogies as a function of working memory capacity", x = 0.5, y = 0.93, size=16)

f.savefig('FAN_WMC_mean.png')

# %%
# correlations

# %%
corrs = pd.DataFrame()

corrs['EPOCH NO'] = np.arange(24)
corrs['LEVEL EASY CORR '] = corr_lev_easy['AVG_RMx'] 
corrs['LEVEL MED CORR'] = corr_lev_med['AVG_RMx'] 
corrs['LEVEL HARD CORR'] = corr_lev_hard['AVG_RMx'] 

corrs['LEVEL EASY ERR'] = err_lev_easy['AVG_RMx']
corrs['LEVEL MED ERR'] = err_lev_med['AVG_RMx'] 
corrs['LEV HARD ERR '] = err_lev_hard['AVG_RMx']

# %%
corrs.corr()['EPOCH NO']

# %%
corrs
